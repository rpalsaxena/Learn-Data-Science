# %% [markdown]
# To better understand what our data is saying, we always need some graphical diagrams.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 10, 100)

# %%
plt.plot(x, x, label='linear')
plt.legend()
plt.show()
